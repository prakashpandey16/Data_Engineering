# %%
import numpy as np
import matplotlib.pyplot as plt
ax = plt.axes(projection = "3d")
x  = np.arange(0,50,0.1)
y = np.arange(0,50,0.1)
z = np.cos(x+y)
ax.plot(x,y,z)
ax.set_title("3D plot")
# ax.set_xlable()
# ax.set_ylable()
# ax.set_zlable()
plt.savefig("3D plot",dpi = 500)
